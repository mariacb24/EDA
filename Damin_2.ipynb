# %% [markdown]
# <a href="https://colab.research.google.com/github/mariacb24/EDA/blob/main/Damin_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from google.colab import drive
drive.mount('/content/drive')

# Replace 'path/to/your/dataset.xls' with the actual path to your Excel file in Google Drive
file_path = '/content/drive/My Drive/Data Mining/dataset.xls'

# Read the Excel file into a pandas DataFrame
df = pd.read_excel(file_path)

# Now you can work with the data in the DataFrame 'df'
print(df.head())
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#    no         diagnosa     institusi     area                          rumah  \
# 0   1  hiperkolesterol   rumah sakit  bandung                   rs borromeus
# 1   2   hiperlipidemia  laboratorium    garut                            NaN
# 2   3   hiperlipidemia    poliklinik    garut  klinik bhakti ip kosaka garut
# 3   4          vertigo    poliklinik    garut  klinik bhakti ip kosaka garut
# 4   5         check up  laboratorium    garut                            NaN
#
#   tipe  biaya_berobat
# 0  NaN      1172500.0
# 1  NaN       454000.0
# 2  NaN        59000.0
# 3  NaN        80500.0
# 4  NaN       586000.0

# %%
# Find the mode of the 'institusi' column
mode_institusi = df['institusi'].mode()[0]

# Fill NaN values in 'institusi' with the mode
df['institusi'] = df['institusi'].fillna(mode_institusi)

df
# Out:
#          no         diagnosa     institusi     area  \
# 0         1  hiperkolesterol   rumah sakit  bandung
# 1         2   hiperlipidemia  laboratorium    garut
# 2         3   hiperlipidemia    poliklinik    garut
# 3         4          vertigo    poliklinik    garut
# 4         5         check up  laboratorium    garut
# ...     ...              ...           ...      ...
# 9995   9996      pemeriksaan        apotek    garut
# 9996   9997      pemeriksaan        apotek    garut
# 9997   9998      pemeriksaan   rumah sakit  bandung
# 9998   9999      pemeriksaan   rumah sakit  bandung
# 9999  10000      pemeriksaan        apotek    garut
#
#                               rumah         tipe    biaya_berobat_class
# 0                      rs borromeus  dokter umum  1.000.001 - 2.000.000
# 1                  klinik bhakti ip  dokter umum    750.001 - 1.000.000
# 2     klinik bhakti ip kosaka garut  dokter umum               <100.000
# ...

# %%
# Find the mode of the 'area' column
mode_area = df['area'].mode()[0]

# Fill NaN values in 'area' with the mode
df['area'] = df['area'].fillna(mode_area)

df
# Out:
#          no         diagnosa     institusi     area  \
# 0         1  hiperkolesterol   rumah sakit  bandung
# 1         2   hiperlipidemia  laboratorium    garut
# 2         3   hiperlipidemia    poliklinik    garut
# 3         4          vertigo    poliklinik    garut
# 4         5         check up  laboratorium    garut
# ...     ...              ...           ...      ...
# 9995   9996      pemeriksaan        apotek    garut
# 9996   9997      pemeriksaan        apotek    garut
# 9997   9998      pemeriksaan   rumah sakit  bandung
# 9998   9999      pemeriksaan   rumah sakit  bandung
# 9999  10000      pemeriksaan        apotek    garut
#
#                               rumah         tipe    biaya_berobat_class
# 0                      rs borromeus  dokter umum  1.000.001 - 2.000.000
# 1                  klinik bhakti ip  dokter umum    750.001 - 1.000.000
# 2     klinik bhakti ip kosaka garut  dokter umum               <100.000
# ...

# %%
mode_rumah = df['rumah'].mode()[0]

# Fill NaN values in 'rumah' with the mode
df['rumah'].fillna(mode_rumah, inplace=True)

df
# Out:
# <ipython-input-17-0d8662ffc3e8>:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['rumah'].fillna(mode_rumah, inplace=True)
#          no         diagnosa     institusi     area  \
# 0         1  hiperkolesterol   rumah sakit  bandung
# 1         2   hiperlipidemia  laboratorium    garut
# 2         3   hiperlipidemia    poliklinik    garut
# 3         4          vertigo    poliklinik    garut
# 4         5         check up  laboratorium    garut
# ...     ...              ...           ...      ...
# ...

# %%
mode_tipe = df['tipe'].mode()[0]

# Fill NaN values in 'tipe' with the mode
df['tipe'].fillna(mode_tipe, inplace=True)

df
# Out:
# <ipython-input-18-a1ffac332342>:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['tipe'].fillna(mode_tipe, inplace=True)
#          no         diagnosa     institusi     area  \
# 0         1  hiperkolesterol   rumah sakit  bandung
# 1         2   hiperlipidemia  laboratorium    garut
# 2         3   hiperlipidemia    poliklinik    garut
# 3         4          vertigo    poliklinik    garut
# 4         5         check up  laboratorium    garut
# ...     ...              ...           ...      ...
# ...

# %%
# Create a function to categorize the 'biaya_berobat' column into quantiles
def categorize_biaya(biaya):
    if biaya <= df.biaya_berobat.quantile(0.25):
        return '<100.000'
    elif biaya <= df.biaya_berobat.quantile(0.50):
        return '500.001 - 750.000'
    elif biaya <= df.biaya_berobat.quantile(0.75):
        return '750.001 - 1.000.000'
    elif biaya <= df.biaya_berobat.quantile(1):
        return '1.000.001 - 2.000.000'
    else:
        return '2.000.001 - 6.000.000'

# Apply the function to create a new column 'biaya_berobat_class'
df['biaya_berobat_class'] = df['biaya_berobat'].apply(categorize_biaya)

df
# Out:
#          no         diagnosa     institusi     area  \
# 0         1  hiperkolesterol   rumah sakit  bandung
# 1         2   hiperlipidemia  laboratorium    garut
# 2         3   hiperlipidemia    poliklinik    garut
# 3         4          vertigo    poliklinik    garut
# 4         5         check up  laboratorium    garut
# ...     ...              ...           ...      ...
# 9995   9996      pemeriksaan        apotek    garut
# 9996   9997      pemeriksaan        apotek    garut
# 9997   9998      pemeriksaan   rumah sakit  bandung
# 9998   9999      pemeriksaan   rumah sakit  bandung
# 9999  10000      pemeriksaan        apotek    garut
#
#                               rumah         tipe  biaya_berobat  \
# 0                      rs borromeus  dokter umum      1172500.0
# 1                  klinik bhakti ip  dokter umum       454000.0
# 2     klinik bhakti ip kosaka garut  dokter umum        59000.0
# 3     klinik bhakti ip kosaka garut  dokter umum        80500.0
# ...

# %%
# Drop the 'biaya_berobat' column
df = df.drop('biaya_berobat', axis=1)

df
# Out:
#          no         diagnosa     institusi     area  \
# 0         1  hiperkolesterol   rumah sakit  bandung
# 1         2   hiperlipidemia  laboratorium    garut
# 2         3   hiperlipidemia    poliklinik    garut
# 3         4          vertigo    poliklinik    garut
# 4         5         check up  laboratorium    garut
# ...     ...              ...           ...      ...
# 9995   9996      pemeriksaan        apotek    garut
# 9996   9997      pemeriksaan        apotek    garut
# 9997   9998      pemeriksaan   rumah sakit  bandung
# 9998   9999      pemeriksaan   rumah sakit  bandung
# 9999  10000      pemeriksaan        apotek    garut
#
#                               rumah         tipe    biaya_berobat_class
# 0                      rs borromeus  dokter umum  1.000.001 - 2.000.000
# 1                  klinik bhakti ip  dokter umum    750.001 - 1.000.000
# 2     klinik bhakti ip kosaka garut  dokter umum               <100.000
# ...

# %% [markdown]
# # Analisis data setiap kolom

# %%
import matplotlib.pyplot as plt

# Create a histogram for the 'no' column
plt.hist(df['no'], bins=10)  # Adjust the number of bins as needed
plt.xlabel('No')
plt.ylabel('Frequency')
plt.title('Histogram of No')
plt.show()

# %%
# Create a histogram for the 'diagnosa' column
plt.hist(df['diagnosa'], bins=10)  # Adjust the number of bins as needed
plt.xlabel('Diagnosa')
plt.ylabel('Frequency')
plt.title('Histogram of Diagnosa')
plt.show()

# %%
# Create a histogram for the 'institusi' column
plt.hist(df['institusi'], bins=10)  # Adjust the number of bins as needed
plt.xlabel('Institusi')
plt.ylabel('Frequency')
plt.title('Histogram of Institusi')
plt.show()

# %%
# Create a histogram for the 'area' column
plt.hist(df['area'], bins=10)  # Adjust the number of bins as needed
plt.xlabel('Area')
plt.ylabel('Frequency')
plt.title('Histogram of Area')
plt.show()

# %%
# Create a histogram for the 'rumah' column
plt.hist(df['rumah'], bins=10)  # Adjust the number of bins as needed
plt.xlabel('Rumah')
plt.ylabel('Frequency')
plt.title('Histogram of Rumah')
plt.show()

# %%
# Create a histogram for the 'tipe' column
plt.hist(df['tipe'], bins=10)  # Adjust the number of bins as needed
plt.xlabel('Tipe')
plt.ylabel('Frequency')
plt.title('Histogram of Tipe')
plt.show()

# %%
# Create a histogram for the 'biaya_berobat_class' column
plt.hist(df['biaya_berobat_class'], bins=10)  # Adjust the number of bins as needed
plt.xlabel('Biaya Berobat Class')
plt.ylabel('Frequency')
plt.title('Histogram of Biaya Berobat Class')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.show()

# %%
# prompt: buatkan scatter plot setiap kolom

for column in df.columns:
  try:
    plt.figure(figsize=(8, 6))
    plt.scatter(df.index, df[column])
    plt.xlabel("Index")
    plt.ylabel(column)
    plt.title(f"Scatter Plot of {column}")
    plt.show()
  except Exception as e:
    print(f"Error creating scatter plot for {column}: {e}")

# %% [markdown]
# # Bagian Baru
